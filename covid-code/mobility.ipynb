# %%
import numpy as np 
import matplotlib.pyplot as plt 
import matplotlib.colors as mcolors
import pandas as pd 
import seaborn as sns
#import plotly.graph_objs as go
# %matplotlib inline

# %%
df_mobility = pd.read_excel('E:\\Data_Urang\Informatics_Research_Centre\project-covid\Mobilitas\mobilitas_ppkm_mikro_dki_6juli_25juli.xlsx')
df_mobility
# Out:
#    country_region_code country_region sub_region_1  sub_region_2  metro_area  \
# 0                   ID      Indonesia      Jakarta           NaN         NaN
# 1                   ID      Indonesia      Jakarta           NaN         NaN
# 2                   ID      Indonesia      Jakarta           NaN         NaN
# 3                   ID      Indonesia      Jakarta           NaN         NaN
# 4                   ID      Indonesia      Jakarta           NaN         NaN
# 5                   ID      Indonesia      Jakarta           NaN         NaN
# 6                   ID      Indonesia      Jakarta           NaN         NaN
# 7                   ID      Indonesia      Jakarta           NaN         NaN
# 8                   ID      Indonesia      Jakarta           NaN         NaN
# 9                   ID      Indonesia      Jakarta           NaN         NaN
# 10                  ID      Indonesia      Jakarta           NaN         NaN
# ...

# %%
df_mobility = df_mobility.drop(['country_region_code', 'country_region', 'sub_region_1', 'sub_region_2', 'metro_area', 'iso_3166_2_code', 'census_fips_code', 'place_id'], axis=1)
df_mobility
# Out:
#           date  retail_and_recreation_percent_change_from_baseline  \
# 0   2021-06-06                                                -19
# 1   2021-06-07                                                -15
# 2   2021-06-08                                                -18
# 3   2021-06-09                                                -16
# 4   2021-06-10                                                -16
# 5   2021-06-11                                                -14
# 6   2021-06-12                                                -16
# 7   2021-06-13                                                -19
# 8   2021-06-14                                                -17
# 9   2021-06-15                                                -22
# 10  2021-06-16                                                -20
# 11  2021-06-17                                                -21
# 12  2021-06-18                                                -21
# ...

# %%
datar = df_mobility[['date']]
print(datar)
# Out:
#           date
# 0   2021-06-06
# 1   2021-06-07
# 2   2021-06-08
# 3   2021-06-09
# 4   2021-06-10
# 5   2021-06-11
# 6   2021-06-12
# 7   2021-06-13
# 8   2021-06-14
# 9   2021-06-15
# 10  2021-06-16
# 11  2021-06-17
# 12  2021-06-18
# 13  2021-06-19
# 14  2021-06-20
# 15  2021-06-21
# 16  2021-06-22
# 17  2021-06-23
# 18  2021-06-24
# 19  2021-06-25

# %%
date_data = df_mobility[['date','retail_and_recreation_percent_change_from_baseline','grocery_and_pharmacy_percent_change_from_baseline','parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline', 'workplaces_percent_change_from_baseline','residential_percent_change_from_baseline']]
date_data = df_mobility.groupby(["date"]).sum().reset_index()

# %%
date_data.plot('date',['retail_and_recreation_percent_change_from_baseline','grocery_and_pharmacy_percent_change_from_baseline','parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline', 'workplaces_percent_change_from_baseline','residential_percent_change_from_baseline'],kind='bar',figsize=(15,10), fontsize=10, rot=30)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_mobility_clean1 = df_mobility.drop(['date'], axis=1)
df_mobility_clean1
# Out:
#     retail_and_recreation_percent_change_from_baseline  \
# 0                                                 -19
# 1                                                 -15
# 2                                                 -18
# 3                                                 -16
# 4                                                 -16
# 5                                                 -14
# 6                                                 -16
# 7                                                 -19
# 8                                                 -17
# 9                                                 -22
# 10                                                -20
# 11                                                -21
# 12                                                -21
# 13                                                -27
# 14                                                -32
# 15                                                -25
# ...

# %%
df_mobility_clean1.corr().abs()
# Out:
#                                                     retail_and_recreation_percent_change_from_baseline  \
# retail_and_recreation_percent_change_from_baseline                                           1.000000
# grocery_and_pharmacy_percent_change_from_baseline                                            0.820214
# parks_percent_change_from_baseline                                                           0.935234
# transit_stations_percent_change_from_baseline                                                0.686129
# workplaces_percent_change_from_baseline                                                      0.186258
# residential_percent_change_from_baseline                                                     0.503110
#
#                                                     grocery_and_pharmacy_percent_change_from_baseline  \
# retail_and_recreation_percent_change_from_baseline                                           0.820214
# ...

# %%
col = ['retail_and_recreation','grocery_and_pharmacy','parks','transit_stations','workplaces','residential']

df_mobility_clean1.columns = col

# %%
df_mobility_clean1
# Out:
#     retail_and_recreation  grocery_and_pharmacy  parks  transit_stations  \
# 0                     -19                     5    -45               -22
# 1                     -15                    10    -38               -30
# 2                     -18                     6    -41               -31
# 3                     -16                     6    -39               -30
# 4                     -16                     7    -37               -30
# 5                     -14                     7    -33               -30
# 6                     -16                    11    -36               -22
# 7                     -19                     5    -42               -23
# 8                     -17                     7    -36               -30
# 9                     -22                     1    -43               -32
# 10                    -20                     3    -42               -32
# 11                    -21                     1    -42               -35
# ...

# %%
df_mobility_clean1.to_excel('E:\Data_Urang\Informatics_Research_Centre\project-covid\Perekonomian\df_mobility.xls')
# Out:
# <ipython-input-18-c3c2360632fb>:1: FutureWarning: As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#   df_mobility_clean1.to_excel('E:\Data_Urang\Informatics_Research_Centre\project-covid\Perekonomian\df_mobility.xls')
