# %%
# Basic Library
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from scipy.stats import skew

# Model Building
import statsmodels.api as sm

# %%
#Untuk membaca data training dan data testing
data_train = pd.read_excel('E:\Data_Urang\Informatics_Research_Centre\PPKM-Covid-Analysis\covid-code\support_vector_machine\index_gabungan_train.xlsx')
data_test = pd.read_excel('E:\Data_Urang\Informatics_Research_Centre\PPKM-Covid-Analysis\covid-code\support_vector_machine\index_gabungan_test.xlsx')

# %%
data_train
# Out:
#          Date  New_Cases  New_Deaths  New_Recovered  New_Active_Cases  \
# 0    7/6/2021       9439         137           6100              3202
# 1    7/7/2021       9365         142           3655              5568
# 2    7/8/2021      12974         136          10854              1984
# 3    7/9/2021      13111         138          15029             -2056
# 4   7/10/2021      12920          87          16839             -4006
# 5   7/11/2021      13133          46          20602             -7515
# 6   7/12/2021      14622         134          20477             -5989
# 7   7/13/2021      12183          68           4571              7544
# 8   7/14/2021      12669          63           3069              9537
# 9   7/15/2021      12691         141           3034              9516
# 10  7/16/2021      12416         132           8448              3836
# 11  7/17/2021      10168          67          11610             -1509
# ...

# %%
data_test
# Out:
#         Date  New_Cases  New_Deaths  New_Recovered  New_Active_Cases  \
# 0  7/21/2021       5904          95          10545             -4736
# 1  7/22/2021       7060         195          10631             -3766
# 2  7/23/2021       8033         157          14510             -6634
# 3  7/24/2021       8359         151          14528             -6320
# 4  7/25/2021       5394         157          14225             -8988
#
#    Total_Cases  Total_Deaths  Total_Recovered  Total_Active_Cases  \
# 0       763427         10779           662718               89930
# 1       770487         10974           673349               86164
# 2       778520         11131           687859               79530
# 3       786879         11282           702387               73210
# 4       792273         11439           716612               64222
#
#    Location_Level  ...     idr_close    ihsg_high     ihsg_low   ihsg_close  \
# ...

# %%
#Menampilkan atribut yang ada pada dataset
print(data_train.columns.tolist())
# Out:
# ['Date', 'New_Cases', 'New_Deaths', 'New_Recovered', 'New_Active_Cases', 'Total_Cases', 'Total_Deaths', 'Total_Recovered', 'Total_Active_Cases', 'Location_Level', 'Case_Fatality_Rate', 'Case_Recovered_Rate', 'Growth_Factor_of_New_Cases', 'Growth_Factor_of_New_Deaths', 'Unnamed: 0', 'idr_high', 'idr_close', 'ihsg_high', 'ihsg_low', 'ihsg_close', 'retail_and_recreation', 'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces', 'residential']

# %%
#Label yang digunakan
label_train = data_train['New_Deaths'].to_numpy()

#Fitur yang akan diproses
fitur_train = data_train[['New_Recovered', 'New_Active_Cases', 'Total_Cases', 'Total_Deaths', 'Total_Recovered', 
                          'Total_Active_Cases', 'Location_Level', 'Growth_Factor_of_New_Cases', 'Growth_Factor_of_New_Deaths', 
                          'idr_high', 'idr_close', 'ihsg_high', 'ihsg_low', 'ihsg_close', 'retail_and_recreation', 
                          'grocery_and_pharmacy', 'parks', 'transit_stations', 'workplaces', 'residential']].to_numpy()

print(fitur_train)
# Out:
# [[ 6.10000000e+03  3.20200000e+03  6.00929000e+05  8.85400000e+03
#    4.97408000e+05  9.46670000e+04  0.00000000e+00  8.70000000e-01
#    1.14000000e+00  1.45300000e+04  1.44950000e+04  6.05460791e+03
#    6.01306201e+03  6.04711084e+03 -1.90000000e+01  5.00000000e+00
#   -4.50000000e+01 -2.20000000e+01 -1.10000000e+01  5.00000000e+00]
#  [ 3.65500000e+03  5.56800000e+03  6.10294000e+05  8.99600000e+03
#    5.01063000e+05  1.00235000e+05  0.00000000e+00  9.90000000e-01
#    1.04000000e+00  1.45687002e+04  1.45687002e+04  6.06699414e+03
#    6.02230518e+03  6.04403711e+03 -1.50000000e+01  1.00000000e+01
#   -3.80000000e+01 -3.00000000e+01 -2.80000000e+01  9.00000000e+00]
#  [ 1.08540000e+04  1.98400000e+03  6.23268000e+05  9.13200000e+03
#    5.11917000e+05  1.02219000e+05  0.00000000e+00  1.39000000e+00
#    9.60000000e-01  1.45997002e+04  1.45692002e+04  6.08022217e+03
#    6.02860791e+03  6.03989600e+03 -1.80000000e+01  6.00000000e+00
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(fitur_train, label_train, random_state=0)

# %%
from sklearn.svm import LinearSVC

svc = LinearSVC()
svc.fit(X_train, y_train)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LinearSVC()

# %%
y_pred = svc.predict(X_test)
y_pred
# Out:
# array([136, 268,  68, 136], dtype=int64)

# %%
X = index_gabungan[['New_Cases', 'New_Recovered', 'Growth_Factor_of_New_Deaths', 'retail_and_recreation', 'grocery_and_pharmacy', 'parks']]
X = sm.add_constant(X) # adding a constant

olsmod = sm.OLS(index_gabungan['New_Deaths'], X).fit()
print(olsmod.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-3328fee8efb5> in <module>
#       1 from sklearn.metrics import confusion_matrix
#       2
# ----> 3 tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
#       4 accuracy = (tn + tp) / (tn+fp+fn+tp)
#       5
#
# ValueError: too many values to unpack (expected 4)
